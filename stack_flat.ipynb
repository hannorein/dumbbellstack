# %%
from PIL import Image
import numpy as np
import os
from rawkit.raw import Raw
import scipy
from mpldatacursor import datacursor
from scipy import ndimage
import warnings,glob
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # %matplotlib nbagg
    import matplotlib.pyplot as plt
    import matplotlib
files = glob.glob("flat/*.cr2")
print(len(files))
# Out:
# 30

# %%
s = None
for f in files:
    with Raw(filename=f) as raw:
        im, cdesc = raw.bayer_data(include_margin=False)
        im = np.array(im, dtype=np.int64)
    if s is None:
        s = im
    else:
        s += im
# Out:
# /Users/rein/git/rebound/venv/lib/python3.5/site-packages/rawkit/raw.py:269: UserWarning: The image is flipped.
#   "The image is flipped."

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.imshow(s)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
np.save("flat.npy",s//len(files))

# %%
s//len(files)
# Out:
# array([[2310, 2496, 2278, ..., 2570, 2338, 2540],
#        [2476, 2547, 2461, ..., 2600, 2552, 2597],
#        [2307, 2505, 2305, ..., 2552, 2344, 2531],
#        ...,
#        [2311, 2486, 2325, ..., 2540, 2376, 2537],
#        [2471, 2549, 2501, ..., 2596, 2546, 2593],
#        [2324, 2482, 2297, ..., 2555, 2318, 2539]])
